# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import glob
import pysam

# %%
#gathered metadata with Roozbeh's help using:
#Hi Rob, yes you can use this metadata file for mapping cell barcodes to celltypes:
#/oak/stanford/groups/horence/Roozbeh/single_cell_project/utility_files/meta_data/Tabula_Sapiens/TSP1_TSP15_scvi_donor-method_normalized-log1p-scaled_annotated.csv
#It has metadata for all TS data. For example, to get the info for TSP2 10X you can do the following:
# grep "TSP2"  TSP1_TSP15_scvi_donor-method_normalized-log1p-scaled_annotated.csv | grep "10X"
#We use the combination of tissue, compartrment , and consensus_prediction as the ontology for each cell.

meta_df = pd.read_csv(
    '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/tsp2_meta.csv',
)
meta_df.head().T
# Out:
# /share/software/user/open/py-jupyter/1.0.0_py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (8,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                              0  \
# cell_id                               AAACCCAAGGCTTAGG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAAGGCTTAGG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAAGGCTTAGG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                  8635
# n_genes                                                                   2645
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                          macrophage
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                                macrophage
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                      -0.25124
# score_endothelial                                                   -0.0583155
# score_stromal                                                        -0.412487
# score_immune                                                          0.536591
# computational_compartment_assignment                                    immune
# tissue_cell_type                                            Bladder_macrophage
# cell_type_tissue                                            macrophage_Bladder
# cell_ontology_class                                                 macrophage
# free_annotation                                                     macrophage
# manually_annotated                                                        True
# compartment                                                             immune
#
#                                                                              1  \
# cell_id                               AAACCCAAGTTTGTCG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAAGTTTGTCG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAAGTTTGTCG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                  4204
# n_genes                                                                   1558
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                          macrophage
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                                macrophage
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                     -0.154817
# score_endothelial                                                     0.639209
# score_stromal                                                        -0.300821
# score_immune                                                          0.224377
# computational_compartment_assignment                               endothelial
# tissue_cell_type                                            Bladder_macrophage
# cell_type_tissue                                            macrophage_Bladder
# cell_ontology_class                                                 macrophage
# free_annotation                                                     macrophage
# manually_annotated                                                        True
# compartment                                                             immune
#
#                                                                              2  \
# cell_id                               AAACCCACAACCCTAA_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCACAACCCTAA_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCACAACCCTAA_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                  6521
# n_genes                                                                   2315
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                             bladder urothelial cell
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                   bladder urothelial cell
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                       1.46619
# score_endothelial                                                    -0.391884
# score_stromal                                                        -0.359641
# score_immune                                                         -0.447929
# computational_compartment_assignment                                epithelial
# tissue_cell_type                               Bladder_bladder urothelial cell
# cell_type_tissue                               bladder urothelial cell_Bladder
# cell_ontology_class                                    bladder urothelial cell
# free_annotation                                        bladder urothelial cell
# manually_annotated                                                        True
# compartment                                                         epithelial
#
#                                                                              3  \
# cell_id                               AAACCCAGTCATAAAG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAGTCATAAAG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAGTCATAAAG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                 13151
# n_genes                                                                   3297
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                          fibroblast
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                                fibroblast
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                     -0.199814
# score_endothelial                                                    -0.330605
# score_stromal                                                          3.09335
# score_immune                                                          -1.05436
# computational_compartment_assignment                                   stromal
# tissue_cell_type                                            Bladder_fibroblast
# cell_type_tissue                                            fibroblast_Bladder
# cell_ontology_class                                                 fibroblast
# free_annotation                                                     fibroblast
# manually_annotated                                                        True
# compartment                                                            stromal
#
#                                                                              4
# cell_id                               AAACCCAGTCCTATAG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAGTCCTATAG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAGTCCTATAG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                 11809
# n_genes                                                                   2206
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                         plasma cell
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                               plasma cell
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                     -0.147644
# score_endothelial                                                     -0.22228
# score_stromal                                                        -0.199097
# score_immune                                                         0.0318611
# computational_compartment_assignment                                    immune
# tissue_cell_type                                           Bladder_plasma cell
# cell_type_tissue                                           plasma cell_Bladder
# cell_ontology_class                                                plasma cell
# free_annotation                                                    plasma cell
# manually_annotated                                                        True
# compartment                                                             immune

# %%
meta_df['Annotation'].value_counts()
# Out:
# macrophage                               9667
# classical monocyte                       9610
# kidney epithelial cell                   8158
# mesenchymal stem cell                    7130
# memory b cell                            6578
#                                          ...
# intestinal tuft cell                       14
# adventitial cell                           12
# serous cell of epithelium of bronchus       7
# conventional dendritic cell                 3
# plasmacytoid dendritic cell                 2
# Name: Annotation, Length: 84, dtype: int64

# %%
cell_id_to_ann = dict(meta_df[['cell_id','Annotation']].values)

# %%
bam_paths = pd.read_csv('/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/tsp2_paths.csv')
bam_paths
# Out:
#                                                   path             tissue  \
# 0    /scratch/groups/horence/Roozbeh/single_cell_pr...            Bladder
# 1    /scratch/groups/horence/Roozbeh/single_cell_pr...            Bladder
# 2    /scratch/groups/horence/Roozbeh/single_cell_pr...            Bladder
# 3    /scratch/groups/horence/Roozbeh/single_cell_pr...            Bladder
# 4    /scratch/groups/horence/Roozbeh/single_cell_pr...            Bladder
# ..                                                 ...                ...
# 135  /scratch/groups/horence/Roozbeh/single_cell_pr...  Vasculature_Aorta
# 136  /scratch/groups/horence/Roozbeh/single_cell_pr...  Vasculature_Aorta
# 137  /scratch/groups/horence/Roozbeh/single_cell_pr...  Vasculature_Aorta
# 138  /scratch/groups/horence/Roozbeh/single_cell_pr...  Vasculature_Aorta
# 139  /scratch/groups/horence/Roozbeh/single_cell_pr...  Vasculature_Aorta
#
#                         sample_name
# 0           TSP2_Bladder_NA_10X_1_1
# 1           TSP2_Bladder_NA_10X_1_1
# 2           TSP2_Bladder_NA_10X_1_1
# 3           TSP2_Bladder_NA_10X_1_1
# 4           TSP2_Bladder_NA_10X_1_2
# ..                              ...
# 135  TSP2_Vasculature_Aorta_10X_1_1
# 136  TSP2_Vasculature_Aorta_10X_1_2
# 137  TSP2_Vasculature_Aorta_10X_1_2
# 138  TSP2_Vasculature_Aorta_10X_1_2
# 139  TSP2_Vasculature_Aorta_10X_1_2
#
# [140 rows x 3 columns]

# %%
regions = {
    'Timp3_gene':('chr10',86300372,86349506),
    'Timp3_upstream':('chr10',86346902,86347515),
    'Timp3_dwstream':('chr10',86348990,86349699),
    'Flt1_gene':('chr5',147561604,147726011),
    'Flt1_long':('chr5',147560562,147564941),
    'Flt1_short':('chr5',147634121,147640192),
}

region_counts = {
    'region':[],
    'tissue':[],
    'ontology':[],
    'cell_id':[],
}

#Loop through bams
for i,r in bam_paths.iterrows():
    with pysam.AlignmentFile(r['path'],'rb') as bam:
        
        #Loop through regions
        for name,region in regions.items():
            
            #Loop through reads
            for read in bam.fetch(*region):
                _,bc,umi = read.query_name.split('_') #BC/UMI are appended to query_name
                cell_id = bc+'_'+r['sample_name']
                ann = cell_id_to_ann.get(cell_id)
                
                if not ann:
                    continue
                    
                region_counts['region'].append(name)
                region_counts['tissue'].append(r['tissue'])
                region_counts['ontology'].append(ann)
                region_counts['cell_id'].append(cell_id)

# %%
counts_df = pd.DataFrame(region_counts).groupby(['region','tissue','ontology']).agg(
    num_cells = ('cell_id','nunique'),
    read_counts = ('cell_id','count'),
).reset_index()
counts_df
# Out:
#              region             tissue                         ontology  \
# 0         Flt1_gene   BM_vertebralbody                           b cell
# 1         Flt1_gene   BM_vertebralbody       cd4-positive helper t cell
# 2         Flt1_gene   BM_vertebralbody  cd8-positive, alpha-beta t cell
# 3         Flt1_gene   BM_vertebralbody               classical monocyte
# 4         Flt1_gene   BM_vertebralbody                   dendritic cell
# ..              ...                ...                              ...
# 597  Timp3_upstream  Vasculature_Aorta                 endothelial cell
# 598  Timp3_upstream  Vasculature_Aorta                       fibroblast
# 599  Timp3_upstream  Vasculature_Aorta                       macrophage
# 600  Timp3_upstream  Vasculature_Aorta                    pericyte cell
# 601  Timp3_upstream  Vasculature_Aorta               smooth muscle cell
#
#      num_cells  read_counts
# 0            3            4
# 1            7           32
# 2           77          830
# 3            7           31
# 4            2            3
# ..         ...          ...
# 597         12           16
# 598         40           49
# 599         10           18
# 600          5            5
# 601         14           20
#
# [602 rows x 5 columns]

# %%
#Ontologies where Flt1 is highly expressed
counts_df[
    counts_df['region'].eq('Flt1_gene') &
    counts_df['num_cells'].ge(50) &
    counts_df['read_counts'].ge(100)
]['ontology'].unique()
# Out:
# array(['cd8-positive, alpha-beta t cell', 'bladder urothelial cell',
#        'macrophage', 't cell', 'classical monocyte', 'nk cell',
#        'kidney epithelial cell', 'basal cell', 'lung ciliated cell',
#        'type ii pneumocyte', 'cd4-positive, alpha-beta memory t cell',
#        'cd8-positive, alpha-beta memory t cell', 'memory b cell',
#        'naive thymus-derived cd4-positive, alpha-beta t cell',
#        'mesenchymal stem cell', 'cd4-positive helper t cell',
#        'fibroblast'], dtype=object)

# %%
#Ontologies where Timp3 is highly expressed
counts_df[
    counts_df['region'].eq('Timp3_gene') &
    counts_df['num_cells'].ge(50) &
    counts_df['read_counts'].ge(100)
]['ontology'].unique()
# Out:
# array(['type ii pneumocyte', 'mesenchymal stem cell',
#        'skeletal muscle satellite stem cell',
#        'cd4-positive helper t cell', 'fibroblast'], dtype=object)

# %%
for name,g in counts_df.groupby('region'):
    fig = plt.figure(figsize=(6,3))
    ont_tissue_counts = g.pivot_table(
        index = 'tissue',
        columns = 'ontology',
        values = 'read_counts',
        aggfunc = 'sum',
    ).fillna(0)
    
    high_count_onts = ont_tissue_counts.sum().sort_values(ascending=False).index[:20]
    ont_tissue_counts = ont_tissue_counts[high_count_onts]
    
    sns.heatmap(ont_tissue_counts)
    plt.title(name)
    plt.show()
    plt.close()

# %%
meta_df.head().T
# Out:
#                                                                              0  \
# cell_id                               AAACCCAAGGCTTAGG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAAGGCTTAGG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAAGGCTTAGG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                  8635
# n_genes                                                                   2645
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                          macrophage
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                                macrophage
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                      -0.25124
# score_endothelial                                                   -0.0583155
# score_stromal                                                        -0.412487
# score_immune                                                          0.536591
# computational_compartment_assignment                                    immune
# tissue_cell_type                                            Bladder_macrophage
# cell_type_tissue                                            macrophage_Bladder
# cell_ontology_class                                                 macrophage
# free_annotation                                                     macrophage
# manually_annotated                                                        True
# compartment                                                             immune
#
#                                                                              1  \
# cell_id                               AAACCCAAGTTTGTCG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAAGTTTGTCG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAAGTTTGTCG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                  4204
# n_genes                                                                   1558
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                          macrophage
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                                macrophage
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                     -0.154817
# score_endothelial                                                     0.639209
# score_stromal                                                        -0.300821
# score_immune                                                          0.224377
# computational_compartment_assignment                               endothelial
# tissue_cell_type                                            Bladder_macrophage
# cell_type_tissue                                            macrophage_Bladder
# cell_ontology_class                                                 macrophage
# free_annotation                                                     macrophage
# manually_annotated                                                        True
# compartment                                                             immune
#
#                                                                              2  \
# cell_id                               AAACCCACAACCCTAA_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCACAACCCTAA_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCACAACCCTAA_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                  6521
# n_genes                                                                   2315
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                             bladder urothelial cell
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                   bladder urothelial cell
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                       1.46619
# score_endothelial                                                    -0.391884
# score_stromal                                                        -0.359641
# score_immune                                                         -0.447929
# computational_compartment_assignment                                epithelial
# tissue_cell_type                               Bladder_bladder urothelial cell
# cell_type_tissue                               bladder urothelial cell_Bladder
# cell_ontology_class                                    bladder urothelial cell
# free_annotation                                        bladder urothelial cell
# manually_annotated                                                        True
# compartment                                                         epithelial
#
#                                                                              3  \
# cell_id                               AAACCCAGTCATAAAG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAGTCATAAAG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAGTCATAAAG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                 13151
# n_genes                                                                   3297
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                          fibroblast
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                                fibroblast
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                     -0.199814
# score_endothelial                                                    -0.330605
# score_stromal                                                          3.09335
# score_immune                                                          -1.05436
# computational_compartment_assignment                                   stromal
# tissue_cell_type                                            Bladder_fibroblast
# cell_type_tissue                                            fibroblast_Bladder
# cell_ontology_class                                                 fibroblast
# free_annotation                                                     fibroblast
# manually_annotated                                                        True
# compartment                                                            stromal
#
#                                                                              4
# cell_id                               AAACCCAGTCCTATAG_TSP2_Bladder_NA_10X_1_1
# 10X_run                                                                    NaN
# pilot                                                                      NaN
# tissue                                                                 Bladder
# subtissue                                                                  NaN
# method                                                                     10X
# 10X_sample                                                                 NaN
# 10X_replicate                                                              NaN
# notes                                                                      NaN
# seqrun                                                                       2
# donor                                                                     TSP2
# anatomical_position                                                        NaN
# 10X_barcode                           AAACCCAGTCCTATAG_TSP2_Bladder_NA_10X_1_1
# cDNAplate                                                                  NaN
# libraryplate                                                               NaN
# well                                                                       NaN
# donor_method                                                           TSP210X
# cell_identifier                       AAACCCAGTCCTATAG_TSP2_Bladder_NA_10X_1_1
# decontX_split                                                 TSP2_10X_Bladder
# n_counts                                                                 11809
# n_genes                                                                   2206
# _scvi_batch                                                                 14
# _scvi_labels                                                                 0
# _scvi_local_l_mean                                                     8.95026
# _scvi_local_l_var                                                     0.378781
# _dataset                                                                   NaN
# knn_on_bbknn_pred                                                          NaN
# knn_on_scanorama_pred                                                      NaN
# Annotation                                                         plasma cell
# _labels_annotation                                                         NaN
# scanvi_offline_pred                                                        NaN
# svm_pred                                                                   NaN
# final_annotation_cell_ontology_id                                          NaN
# onclass_pred                                                               NaN
# rf_pred                                                                    NaN
# _batch_annotation                                                          NaN
# knn_on_scvi_offline_pred                                                   NaN
# consensus_percentage                                                         1
# consensus_prediction                                               plasma cell
# Manually Annotated                                                        True
# _ref_subsample                                                           False
# score_epithelial                                                     -0.147644
# score_endothelial                                                     -0.22228
# score_stromal                                                        -0.199097
# score_immune                                                         0.0318611
# computational_compartment_assignment                                    immune
# tissue_cell_type                                           Bladder_plasma cell
# cell_type_tissue                                           plasma cell_Bladder
# cell_ontology_class                                                plasma cell
# free_annotation                                                    plasma cell
# manually_annotated                                                        True
# compartment                                                             immune

# %%
meta_df['Annotation'].eq(meta_df['free_annotation']).all()
# Out:
# False

# %%
meta_df['Annotation'].unique()
# Out:
# array(['macrophage', 'bladder urothelial cell', 'fibroblast',
#        'plasma cell', 't cell', 'myofibroblast cell', 'b cell', 'nk cell',
#        'vein endothelial cell', 'mast cell', 'pericyte cell',
#        'smooth muscle cell', 'capillary endothelial cell',
#        'endothelial cell of lymphatic vessel', 'classical monocyte',
#        'erythrocyte', 'naive b cell', 'cd4-positive helper t cell', nan,
#        'memory b cell', 'intermediate monocyte',
#        'cd8-positive, alpha-beta t cell', 'platelet', 'mature nk t cell',
#        'neutrophil', 'conventional dendritic cell',
#        'non-classical monocyte', 'erythroid progenitor', 'dendritic cell',
#        'hematopoietic stem cell', 'kidney epithelial cell',
#        'endothelial cell', 'immature enterocyte',
#        'intestinal crypt stem cell',
#        'transit amplifying cell of large intestine', 'mature enterocyte',
#        'gut endothelial cell', 'intestinal enteroendocrine cell',
#        'paneth cell of epithelium of large intestine', 'goblet cell',
#        'alveolar fibroblast', 'type ii pneumocyte', 'club cell',
#        'capillary aerocyte', 'basophil', 'basal cell',
#        'cd4-positive, alpha-beta t cell',
#        'lung microvascular endothelial cell', 'respiratory goblet cell',
#        'bronchial smooth muscle cell', 'lung ciliated cell',
#        'pulmonary ionocyte', 'vascular associated smooth muscle cell',
#        'endothelial cell of artery', 'type i pneumocyte',
#        'serous cell of epithelium of bronchus', 'adventitial cell',
#        'mesothelial cell',
#        'naive thymus-derived cd4-positive, alpha-beta t cell',
#        'cd4-positive, alpha-beta memory t cell',
#        'cd8-positive, alpha-beta memory t cell', 'innate lymphoid cell',
#        'cd141-positive myeloid dendritic cell',
#        'cd1c-positive myeloid dendritic cell', 'regulatory t cell',
#        'mesenchymal stem cell', 'endothelial cell of vascular tree',
#        'skeletal muscle satellite stem cell', 'tendon cell',
#        'fast muscle cell', 'slow muscle cell',
#        'transit amplifying cell of small intestine',
#        'paneth cell of epithelium of small intestine',
#        'intestinal tuft cell', 'duodenum glandular cell',
#        'naive thymus-derived cd8-positive, alpha-beta t cell',
#        'plasmacytoid dendritic cell', 'medullary thymic epithelial cell',
#        'monocyte', 'immature natural killer cell', 'thymocyte',
#        'ciliated cell', 'connective tissue cell', 'secretory cell',
#        'epithelial cell'], dtype=object)

# %%
meta_df['free_annotation'].unique()
# Out:
# array(['macrophage', 'bladder urothelial cell', 'fibroblast',
#        'plasma cell', 't cell', 'myofibroblast cell', 'b cell', 'nk cell',
#        'vein endothelial cell', 'mast cell', 'pericyte cell',
#        'smooth muscle cell', 'capillary endothelial cell',
#        'endothelial cell of lymphatic vessel', 'monocyte',
#        'platelet doublet', 'naive b cell', 'CD4 t cell', 'doublet nk',
#        'memory b cell', 'CD8 t cell', 'erythrocyte doublet',
#        'cd8-positive, alpha-beta t cell', 'erythrocyte', 'NK cell',
#        'hematopoietic stem cell', 'NAMPT neutrophil',
#        'myeloid progenitor', 'plasmablast', 'granulocyte',
#        'CD24 Neutrophil', 'cd4-positive helper t cell',
#        'erythroid progenitor', 'dendritic cell', 'kidney epithelial cell',
#        'endothelial cell', 'immature enterocyte',
#        'intestinal crypt stem cell',
#        'transit amplifying cell of large intestine', 'mature enterocyte',
#        'gut endothelial cell', 'intestinal enteroendocrine cell',
#        'paneth cell of epithelium of large intestine', 'goblet cell',
#        'alveolar fibroblast', 'type ii pneumocyte', 'classical monocyte',
#        'club cell', 'capillary aerocyte', 'non-classical monocyte',
#        'basophil', 'basal cell', 'cd4-positive, alpha-beta t cell',
#        'lung microvascular endothelial cell', 'respiratory goblet cell',
#        'bronchial smooth muscle cell', 'intermediate monocyte',
#        'lung ciliated cell', 'pulmonary ionocyte',
#        'vascular associated smooth muscle cell',
#        'endothelial cell of artery', 'type i pneumocyte',
#        'naive thymus-derived cd8-positive, alpha-beta t cell',
#        'serous cell of epithelium of bronchus',
#        'blood vessel endothelial cell', 'adventitial cell',
#        'mesothelial cell', 'antibody secreting cell', 'neutrophil',
#        'naive thymus-derived cd4-positive, alpha-beta t cell',
#        'cd4-positive, alpha-beta memory t cell',
#        'cd8-positive, alpha-beta memory t cell', 'innate lymphoid cell',
#        'mature nk t cell', 'cd141-positive myeloid dendritic cell',
#        'cd1c-positive myeloid dendritic cell', 'regulatory t cell',
#        'mesenchymal stem cell', 'endothelial cell of vascular tree',
#        'skeletal muscle satellite stem cell', 'tendon cell',
#        'fast muscle cell', 'slow muscle cell',
#        'transit amplifying cell of small intestine',
#        'paneth cell of epithelium of small intestine',
#        'intestinal tuft cell', 'duodenum glandular cell',
#        'plasmacytoid dendritic cell', 'medullary thymic epithelial cell',
#        'immature natural killer cell', 'thymocyte', 'ciliated cell',
#        'connective tissue cell', 'secretory cell', 'epithelial cell'],
#       dtype=object)
