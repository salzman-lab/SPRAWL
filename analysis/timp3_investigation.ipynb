# %%
import pandas as pd
pd.options.display.max_rows = 100

# %%
df = pd.read_csv(
    '/oak/stanford/groups/horence/rob/readzs_fork/results/timp3_counts.tsv',
    sep = '\t',
)
df.head()
# Out:
#                                   cell  chrom       pos strand  read_count  \
# 0  L8TX_181211_01_A01_GAGACTTCAATGGCCC  chr10  86345022      +           1
# 1  L8TX_181211_01_A01_ACCTACCTCTGAACGT  chr10  86345707      +           1
# 2  L8TX_181211_01_A01_ACATCGATCATGGCCG  chr10  86345741      +           1
# 3  L8TX_181211_01_A01_CCTACGTCAAATGGCG  chr10  86345881      +           1
# 4  L8TX_181211_01_A01_CTGTACCAGGCACGAT  chr10  86345922      +           1
#
#                  lane            window   mouse
# 0  L8TX_181211_01_A01  chr10_17270_plus  426003
# 1  L8TX_181211_01_A01  chr10_17270_plus  426003
# 2  L8TX_181211_01_A01  chr10_17270_plus  426003
# 3  L8TX_181211_01_A01  chr10_17270_plus  426003
# 4  L8TX_181211_01_A01  chr10_17270_plus  426003

# %%
df.groupby('mouse')['cell'].nunique()
# Out:
# mouse
# 426003    2715
# 427378    2288
# 457909    1876
# 457911    1869
# Name: cell, dtype: int64

# %%
df.groupby(['mouse','cell'])['read_count'].sum().reset_index()
# Out:
#        mouse                                 cell  read_count
# 0     426003  L8TX_181211_01_A01_AAAGGATTCTCTATAC           2
# 1     426003  L8TX_181211_01_A01_AAAGTCCCACTCCACT          22
# 2     426003  L8TX_181211_01_A01_AAATGGAGTTCGGCTG           1
# 3     426003  L8TX_181211_01_A01_AACAAGAAGAAATCCA           1
# 4     426003  L8TX_181211_01_A01_AACAAGAGTCGCTGCA           1
# ...      ...                                  ...         ...
# 8743  457911  L8TX_190430_01_B08_TTTGATCAGGTGGGTT           1
# 8744  457911  L8TX_190430_01_B08_TTTGATCGTTTCGATG           2
# 8745  457911  L8TX_190430_01_B08_TTTGGAGAGGGACCAT           1
# 8746  457911  L8TX_190430_01_B08_TTTGGTTCACGGGCTT           2
# 8747  457911  L8TX_190430_01_B08_TTTGTTGTCCAAACCA           1
#
# [8748 rows x 3 columns]

# %%
df[df['read_count'].gt(2)]
# Out:
#                                       cell  chrom       pos strand  \
# 3796   L8TX_181211_01_G12_CCGTGAGAGGCATCTT  chr10  86349188      +
# 8345   L8TX_181211_01_B01_ATTATCCGTGCCGAAA  chr10  86349258      +
# 9673   L8TX_181211_01_E01_TCTCCGAAGAGGATCC  chr10  86349246      +
# 9784   L8TX_181211_01_E01_GACAGCCGTAGCGAGT  chr10  86349278      +
# 11611  L8TX_181211_01_C01_GATTCGAAGCTCTGTA  chr10  86349200      +
# 11627  L8TX_181211_01_C01_GTGTAACCAAGCTACT  chr10  86349202      +
# 20605  L8TX_190430_01_B08_AGACTCAGTAGTTACC  chr10  86349355      +
#
#        read_count                lane            window   mouse ontology
# 3796            3  L8TX_181211_01_G12  chr10_17270_plus  426003      NaN
# 8345            3  L8TX_181211_01_B01  chr10_17270_plus  427378      Sst
# 9673            3  L8TX_181211_01_E01  chr10_17270_plus  427378      Sst
# 9784            3  L8TX_181211_01_E01  chr10_17270_plus  427378      Sst
# 11611           3  L8TX_181211_01_C01  chr10_17270_plus  427378      Sst
# 11627           3  L8TX_181211_01_C01  chr10_17270_plus  427378    Lamp5
# 20605           3  L8TX_190430_01_B08  chr10_17270_plus  457911      Sst

# %%
meta_df = pd.read_csv(
    '../../../readzs_fork/MOp_10Xv3_metadata.tsv',
    sep = '\t',
)
cell_id_to_ont = dict(meta_df[['cell_id','subclass_label']].values)

# %%
df['ontology'] = df['cell'].map(cell_id_to_ont)
df.head()
# Out:
#                                   cell  chrom       pos strand  read_count  \
# 0  L8TX_181211_01_A01_GAGACTTCAATGGCCC  chr10  86345022      +           1
# 1  L8TX_181211_01_A01_ACCTACCTCTGAACGT  chr10  86345707      +           1
# 2  L8TX_181211_01_A01_ACATCGATCATGGCCG  chr10  86345741      +           1
# 3  L8TX_181211_01_A01_CCTACGTCAAATGGCG  chr10  86345881      +           1
# 4  L8TX_181211_01_A01_CTGTACCAGGCACGAT  chr10  86345922      +           1
#
#                  lane            window   mouse ontology
# 0  L8TX_181211_01_A01  chr10_17270_plus  426003    L5 IT
# 1  L8TX_181211_01_A01  chr10_17270_plus  426003      NaN
# 2  L8TX_181211_01_A01  chr10_17270_plus  426003      NaN
# 3  L8TX_181211_01_A01  chr10_17270_plus  426003      Sst
# 4  L8TX_181211_01_A01  chr10_17270_plus  426003      Sst

# %%
df['ontology'].value_counts()
# Out:
# Sst           5369
# Lamp5         1804
# Vip           1033
# L2/3 IT        888
# L5 IT          885
# Endo           803
# Astro          720
# L6 IT          525
# L6 CT          360
# OPC            236
# Oligo          129
# L5/6 NP         85
# SMC             72
# VLMC            40
# Sncg            37
# Pvalb           27
# L6b             22
# L5 ET           13
# L6 IT Car3       2
# Name: ontology, dtype: int64

# %%
agg_df = df.groupby(['ontology','mouse']).agg(
    num_cells = ('cell','nunique'),
    total_counts = ('read_count','sum'),
).reset_index()

agg_df['counts_per_cell'] = agg_df['total_counts']/agg_df['num_cells']

agg_df
# Out:
#       ontology   mouse  num_cells  total_counts  counts_per_cell
# 0        Astro  426003         94           332         3.531915
# 1        Astro  427378         68           156         2.294118
# 2        Astro  457909         41            89         2.170732
# 3        Astro  457911         65           155         2.384615
# 4         Endo  426003         63           436         6.920635
# 5         Endo  427378         18            64         3.555556
# 6         Endo  457909         27           126         4.666667
# 7         Endo  457911         31           197         6.354839
# 8      L2/3 IT  426003        200           300         1.500000
# 9      L2/3 IT  427378        230           332         1.443478
# 10     L2/3 IT  457909        112           124         1.107143
# 11     L2/3 IT  457911        129           142         1.100775
# 12       L5 ET  427378          1             8         8.000000
# 13       L5 ET  457909          2             5         2.500000
# 14       L5 IT  426003        215           353         1.641860
# 15       L5 IT  427378        204           295         1.446078
# 16       L5 IT  457909        101           131         1.297030
# 17       L5 IT  457911        104           119         1.144231
# 18     L5/6 NP  426003         26            35         1.346154
# 19     L5/6 NP  427378         20            27         1.350000
# 20     L5/6 NP  457909         14            17         1.214286
# 21     L5/6 NP  457911          6             6         1.000000
# 22       L6 CT  426003         56            76         1.357143
# 23       L6 CT  427378         83           130         1.566265
# 24       L6 CT  457909         69            82         1.188406
# 25       L6 CT  457911         73            75         1.027397
# 26       L6 IT  426003         79           118         1.493671
# 27       L6 IT  427378        157           243         1.547771
# 28       L6 IT  457909         67            71         1.059701
# 29       L6 IT  457911         88           101         1.147727
# 30  L6 IT Car3  427378          1             1         1.000000
# 31  L6 IT Car3  457909          1             1         1.000000
# 32         L6b  426003          4             6         1.500000
# 33         L6b  427378          9            12         1.333333
# 34         L6b  457911          4             4         1.000000
# 35       Lamp5  426003        241           784         3.253112
# 36       Lamp5  427378        179           497         2.776536
# 37       Lamp5  457909        130           290         2.230769
# 38       Lamp5  457911        120           267         2.225000
# 39         OPC  426003         29            85         2.931034
# 40         OPC  427378         23            41         1.782609
# 41         OPC  457909         23            48         2.086957
# 42         OPC  457911         30            63         2.100000
# 43       Oligo  426003         17            48         2.823529
# 44       Oligo  427378          6            11         1.833333
# 45       Oligo  457909         18            31         1.722222
# 46       Oligo  457911         19            39         2.052632
# 47       Pvalb  457909          5            11         2.200000
# 48       Pvalb  457911         10            16         1.600000
# 49         SMC  426003          8            59         7.375000
# 50         SMC  457911          3            15         5.000000
# 51        Sncg  426003          6            12         2.000000
# 52        Sncg  427378          2             2         1.000000
# 53        Sncg  457909          8            16         2.000000
# 54        Sncg  457911          7             8         1.142857
# 55         Sst  426003        162          1511         9.327160
# 56         Sst  427378        194          1450         7.474227
# 57         Sst  457909        175          1179         6.737143
# 58         Sst  457911        187          1344         7.187166
# 59        VLMC  426003          8            19         2.375000
# 60        VLMC  427378          4             9         2.250000
# 61        VLMC  457909          1             1         1.000000
# 62        VLMC  457911          8            13         1.625000
# 63         Vip  426003        107           344         3.214953
# 64         Vip  427378         73           285         3.904110
# 65         Vip  457909         82           230         2.804878
# 66         Vip  457911         69           189         2.739130

# %%
agg_df[agg_df['ontology'].isin(['L6 IT','Sst'])]
# Out:
#    ontology   mouse  num_cells  total_counts  counts_per_cell
# 26    L6 IT  426003         79           118         1.493671
# 27    L6 IT  427378        157           243         1.547771
# 28    L6 IT  457909         67            71         1.059701
# 29    L6 IT  457911         88           101         1.147727
# 55      Sst  426003        162          1511         9.327160
# 56      Sst  427378        194          1450         7.474227
# 57      Sst  457909        175          1179         6.737143
# 58      Sst  457911        187          1344         7.187166

# %%
df
# Out:
#                                       cell  chrom       pos strand  \
# 0      L8TX_181211_01_A01_GAGACTTCAATGGCCC  chr10  86345022      +
# 1      L8TX_181211_01_A01_ACCTACCTCTGAACGT  chr10  86345707      +
# 2      L8TX_181211_01_A01_ACATCGATCATGGCCG  chr10  86345741      +
# 3      L8TX_181211_01_A01_CCTACGTCAAATGGCG  chr10  86345881      +
# 4      L8TX_181211_01_A01_CTGTACCAGGCACGAT  chr10  86345922      +
# ...                                    ...    ...       ...    ...
# 20727  L8TX_190430_01_B08_GAGTTACTCTCCGTGT  chr10  86349413      +
# 20728  L8TX_190430_01_B08_AAGCATCAGCAGTCTT  chr10  86349414      +
# 20729  L8TX_190430_01_B08_CCACACTTCGGTAAGG  chr10  86349414      +
# 20730  L8TX_190430_01_B08_GTTGAACCACGTTCGG  chr10  86349414      +
# 20731  L8TX_190430_01_B08_TACCCACAGGCCTTGC  chr10  86349414      +
#
#        read_count                lane            window   mouse ontology
# 0               1  L8TX_181211_01_A01  chr10_17270_plus  426003    L5 IT
# 1               1  L8TX_181211_01_A01  chr10_17270_plus  426003      NaN
# 2               1  L8TX_181211_01_A01  chr10_17270_plus  426003      NaN
# 3               1  L8TX_181211_01_A01  chr10_17270_plus  426003      Sst
# 4               1  L8TX_181211_01_A01  chr10_17270_plus  426003      Sst
# ...           ...                 ...               ...     ...      ...
# 20727           1  L8TX_190430_01_B08  chr10_17270_plus  457911     VLMC
# 20728           1  L8TX_190430_01_B08  chr10_17270_plus  457911      Sst
# 20729           1  L8TX_190430_01_B08  chr10_17270_plus  457911      Sst
# 20730           1  L8TX_190430_01_B08  chr10_17270_plus  457911      NaN
# 20731           1  L8TX_190430_01_B08  chr10_17270_plus  457911      Vip
#
# [20732 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for mouse,mouse_df in df.groupby('mouse'):
    sns.ecdfplot(
        x = 'pos',
        hue = 'ontology',
        data = mouse_df[
            mouse_df['ontology'].isin(['Sst','L6 IT'])
        ],
        hue_order = ['L6 IT','Sst'],
    )
    plt.title('Mouse-id = {}'.format(mouse))
    plt.show()
    plt.close()
