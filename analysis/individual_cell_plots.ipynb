# %%
import pandas as pd
import numpy as np
import sys

import matplotlib.pyplot as plt

sys.path.append('../src')
import SRRS
from SRRS import plotting

# %% [markdown]
# ### Plotting random cells for Timp3 from either L6_IT or SMC to show peripheral differences

# %%
#first find the cell_ids that I'm interested in from the gene/cell output table
gene_cell_df = pd.read_csv('/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/outputs/gene_cell/MOp_peripheral_ReadZs_gene_ontology.csv')

gene_cell_df = gene_cell_df[
    gene_cell_df['ontology'].isin(['L6 IT','Sst']) &
    gene_cell_df['gene'].eq('Timp3') &
    gene_cell_df['num_spots'].ge(500) #want visually "dense" cells for plotting
]
gene_cell_df['mouse_sample'] = 'mouse'+gene_cell_df['mouse'].astype(str)+'sample'+gene_cell_df['sample'].astype(str)+'.hdf5'
#gene_cell_df = gene_cell_df[['cell_id','ontology','score','variance','mouse_sample']]
gene_cell_df
# Out:
#              metric                                  cell_id  num_spots  \
# 11066    peripheral  111224926392630212160278934965632123769       1175
# 12505    peripheral  112648164421818832458832345016894387743       1017
# 23358    peripheral  123723356376229754610115939505968724825       1192
# 34369    peripheral  136717447085671937120241694290555474406        545
# 54081    peripheral  156531593043134580079198601385059303486       1014
# ...             ...                                      ...        ...
# 3465553  peripheral  336267492658158463781688736437660452228       1074
# 3504180  peripheral   55824625741938588634687216110989015160       1129
# 3510519  peripheral    6043178046984074953134207573372326917        617
# 3512149  peripheral   61663256578270467796366138864714040808        938
# 3518925  peripheral   67162672766033638423365508669814880063        825
#
#           gene  num_gene_spots  median_rank     score  variance  mouse  \
# 11066    Timp3              16        731.5 -0.244463  0.051707      2
# 12505    Timp3               6        349.5  0.313976  0.106825      2
# 23358    Timp3              10        657.5 -0.102435  0.075311      2
# 34369    Timp3               9        354.0 -0.297794  0.089902      2
# 54081    Timp3              14        469.0  0.076012  0.057698      2
# ...        ...             ...          ...       ...       ...    ...
# 3465553  Timp3              10        303.5  0.436160  0.075262      1
# 3504180  Timp3              24        592.5 -0.048759  0.036234      1
# 3510519  Timp3              15        176.0  0.431818  0.057673      1
# 3512149  Timp3              10        353.5  0.247599  0.075190      1
# 3518925  Timp3              15        542.0 -0.313107  0.057964      1
#
#          sample  replicate sample_id ontology        mouse_sample
# 11066         4          1      m2s4      Sst  mouse2sample4.hdf5
# 12505         4          1      m2s4      Sst  mouse2sample4.hdf5
# 23358         4          1      m2s4      Sst  mouse2sample4.hdf5
# 34369         4          1      m2s4      Sst  mouse2sample4.hdf5
# 54081         4          1      m2s4      Sst  mouse2sample4.hdf5
# ...         ...        ...       ...      ...                 ...
# 3465553       5          1      m1s5      Sst  mouse1sample5.hdf5
# 3504180       5          1      m1s5      Sst  mouse1sample5.hdf5
# 3510519       5          1      m1s5      Sst  mouse1sample5.hdf5
# 3512149       5          1      m1s5      Sst  mouse1sample5.hdf5
# 3518925       5          1      m1s5      Sst  mouse1sample5.hdf5
#
# [416 rows x 14 columns]

# %%
gene_cell_df['ontology'].value_counts()
# Out:
# Sst      363
# L6 IT     53
# Name: ontology, dtype: int64

# %%
gene_cell_df.groupby('ontology')['score'].mean()
# Out:
# ontology
# L6 IT    0.428178
# Sst      0.050723
# Name: score, dtype: float64

# %%
#Plot random L6 IT cells
n_plots = 5
np.random.seed(1) #for reproducibility

stem = '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/inputs/'
for i,r in gene_cell_df[gene_cell_df['ontology'].eq('L6 IT')].sample(n_plots).iterrows():
    sample = SRRS.HDF5(stem+r['mouse_sample'])
    cell = sample.get_cells_by_id(r['cell_id'])[0]
    title = '{} cell has Timp3 peripheral score {:.2f}'.format(r['ontology'],r['score'])
    print(title)
    
    plotting.plot_cell_zslices(cell,gene_colors={'Timp3':'red'})
    plt.suptitle(title)
    fmts = [
        r['ontology'].replace('/','').replace(' ','_'),
        r['cell_id'],
        'timp3',
        '{:.2f}'.format(r['score']),
    ]
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_zslices.svg'.format(*fmts))
    plt.close()
    
    plotting.plot_cell_3D(cell,gene_colors={'Timp3':'red'})
    plt.title(title)
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_3d.svg'.format(*fmts))
    plt.close()
# Out:
# L6 IT cell has Timp3 peripheral score 0.51
# L6 IT cell has Timp3 peripheral score 0.07
# L6 IT cell has Timp3 peripheral score 0.31
# L6 IT cell has Timp3 peripheral score -0.26
# L6 IT cell has Timp3 peripheral score 0.28

# %%
#Plot random Sst IT cells
n_plots = 5
np.random.seed(1) #for reproducibility

stem = '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/inputs/'
for i,r in gene_cell_df[gene_cell_df['ontology'].eq('Sst')].sample(n_plots).iterrows():
    sample = SRRS.HDF5(stem+r['mouse_sample'])
    cell = sample.get_cells_by_id(r['cell_id'])[0]
    title = '{} cell has Timp3 peripheral score {:.2f}'.format(r['ontology'],r['score'])
    print(title)
    
    plotting.plot_cell_zslices(cell,gene_colors={'Timp3':'red'})
    plt.suptitle(title)
    fmts = [
        r['ontology'].replace('/','').replace(' ','_'),
        r['cell_id'],
        'timp3',
        '{:.2f}'.format(r['score']),
    ]
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_zslices.svg'.format(*fmts))
    plt.close()
    
    plotting.plot_cell_3D(cell,gene_colors={'Timp3':'red'})
    plt.title(title)
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_3d.svg'.format(*fmts))
    plt.close()
# Out:
# Sst cell has Timp3 peripheral score -0.04
# Sst cell has Timp3 peripheral score 0.30
# Sst cell has Timp3 peripheral score -0.12
# Sst cell has Timp3 peripheral score -0.10
# Sst cell has Timp3 peripheral score 0.89

# %%
import importlib
importlib.reload(plotting)

#Plot random Endo cells
n_plots = 5
np.random.seed(1) #for reproducibility

plt.close('all')

stem = '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/inputs/'
for i,r in gene_cell_df[gene_cell_df['ontology'].eq('Endo')].sample(n_plots).iterrows():
    sample = SRRS.HDF5(stem+r['mouse_sample'])
    cell = sample.get_cells_by_id(r['cell_id'])[0]
    title = '{} cell has Timp3 peripheral score {:.2f}'.format(r['ontology'],r['score'])
    print(title)
    
    plotting.plot_cell_zslices(cell,gene_colors={'Timp3':'red'})
    plt.suptitle(title)
    fmts = [
        r['ontology'].replace('/','').replace(' ','_'),
        r['cell_id'],
        'timp3',
        '{:.2f}'.format(r['score']),
    ]
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_zslices.svg'.format(*fmts))
    plt.close()
    
    plotting.plot_cell_3D(cell,gene_colors={'Timp3':'red'})
    plt.title(title)
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_3d.svg'.format(*fmts))
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-cf25cd351e5d> in <module>()
#       9
#      10 stem = '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/inputs/'
# ---> 11 for i,r in gene_cell_df[gene_cell_df['ontology'].eq('Endo')].sample(n_plots).iterrows():
#      12     sample = SRRS.HDF5(stem+r['mouse_sample'])
#      13     cell = sample.get_cells_by_id(r['cell_id'])[0]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4993             )
#    4994
# -> 4995         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4996         return self.take(locs, axis=axis)
#    4997
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
# Out:
# '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/inputs/mouse1sample1.hdf5'

# %%
sample.get_cells_by_id('99518086998411234552327278589933473106')

# %%
fig = plotting.plot_cell_3D(cells[0])
plt.show()
plt.close()

# %% [markdown]
# # Plotting Flt1 random cells between VLMC and L5 IT to see any differences

# %%
#first find the cell_ids that I'm interested in from the gene/cell output table
gene_cell_df = pd.read_csv('/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/outputs/gene_cell/MOp_peripheral_ReadZs_gene_ontology.csv')

gene_cell_df = gene_cell_df[
    gene_cell_df['ontology'].isin(['L5 IT','VLMC']) &
    gene_cell_df['gene'].eq('Flt1') &
    gene_cell_df['num_spots'].ge(500) #want visually "dense" cells for plotting
]
gene_cell_df['mouse_sample'] = 'mouse'+gene_cell_df['mouse'].astype(str)+'sample'+gene_cell_df['sample'].astype(str)+'.hdf5'
#gene_cell_df = gene_cell_df[['cell_id','ontology','score','variance','mouse_sample']]
gene_cell_df
# Out:
#              metric                                  cell_id  num_spots  gene  \
# 12147    peripheral  112241079216048970646177567296849637529        592  Flt1
# 48876    peripheral  151474480921610008843828817099193350551        733  Flt1
# 93173    peripheral  196562005419384853973911661121158467890        529  Flt1
# 96321    peripheral  199383595679567987493829043882696237917        521  Flt1
# 131708   peripheral  234426466227798799713824883806619900845        590  Flt1
# ...             ...                                      ...        ...   ...
# 3493752  peripheral   48636629648091737083598638297192913992        732  Flt1
# 3542827  peripheral   84160524639246723749372393954042621628        506  Flt1
# 3542944  peripheral   84258051624625387623325703672384503109        511  Flt1
# 3557053  peripheral   94194155471532350639433658067223319504       1271  Flt1
# 3558743  peripheral   95061549232310380241305602271896971131       1705  Flt1
#
#          num_gene_spots  median_rank     score  variance  mouse  sample  \
# 12147                 6        133.5  0.551607  0.106596      2       4
# 48876                 6        500.0 -0.363388  0.106702      2       4
# 93173                 7        158.0  0.405303  0.110265      2       4
# 96321                19        212.0  0.188462  0.046148      2       4
# 131708               33        459.0 -0.555178  0.027111      2       4
# ...                 ...          ...       ...       ...    ...     ...
# 3493752               8        256.0  0.302326  0.088279      1       5
# 3542827               5        148.0  0.417822  0.142287      1       5
# 3542944              10        248.5  0.029412  0.074713      1       5
# 3557053              12        579.5  0.088976  0.065466      1       5
# 3558743               7        161.0  0.812207  0.110850      1       5
#
#          replicate sample_id ontology        mouse_sample
# 12147            1      m2s4     VLMC  mouse2sample4.hdf5
# 48876            1      m2s4     VLMC  mouse2sample4.hdf5
# 93173            1      m2s4     VLMC  mouse2sample4.hdf5
# 96321            1      m2s4     VLMC  mouse2sample4.hdf5
# 131708           1      m2s4     VLMC  mouse2sample4.hdf5
# ...            ...       ...      ...                 ...
# 3493752          1      m1s5     VLMC  mouse1sample5.hdf5
# 3542827          1      m1s5     VLMC  mouse1sample5.hdf5
# 3542944          1      m1s5     VLMC  mouse1sample5.hdf5
# 3557053          1      m1s5     VLMC  mouse1sample5.hdf5
# 3558743          1      m1s5    L5 IT  mouse1sample5.hdf5
#
# [202 rows x 14 columns]

# %%
gene_cell_df['ontology'].value_counts()
# Out:
# VLMC     162
# L5 IT     40
# Name: ontology, dtype: int64

# %%
gene_cell_df.groupby('ontology')['score'].mean()
# Out:
# ontology
# L5 IT    0.483821
# VLMC     0.052682
# Name: score, dtype: float64

# %%
#Plot random L5 IT cells
n_plots = 5
np.random.seed(1) #for reproducibility

stem = '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/inputs/'
for i,r in gene_cell_df[gene_cell_df['ontology'].eq('L5 IT')].sample(n_plots).iterrows():
    sample = SRRS.HDF5(stem+r['mouse_sample'])
    cell = sample.get_cells_by_id(r['cell_id'])[0]
    title = '{} cell has Flt1 peripheral score {:.2f}'.format(r['ontology'],r['score'])
    print(title)
    
    plotting.plot_cell_zslices(cell,gene_colors={'Flt1':'red'})
    plt.suptitle(title)
    fmts = [
        r['ontology'].replace('/','').replace(' ','_'),
        r['cell_id'],
        'flt1',
        '{:.2f}'.format(r['score']),
    ]
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_zslices.svg'.format(*fmts))
    plt.close()
    
    plotting.plot_cell_3D(cell,gene_colors={'Flt1':'red'})
    plt.title(title)
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_3d.svg'.format(*fmts))
    plt.close()
# Out:
# L5 IT cell has Flt1 peripheral score 0.51
# L5 IT cell has Flt1 peripheral score 0.59
# L5 IT cell has Flt1 peripheral score -0.19
# L5 IT cell has Flt1 peripheral score -0.16
# L5 IT cell has Flt1 peripheral score 0.20

# %%
#Plot random VLMC cells
n_plots = 5
np.random.seed(1) #for reproducibility

stem = '/oak/stanford/groups/horence/rob/isoform_localizations/SRRS/inputs/'
for i,r in gene_cell_df[gene_cell_df['ontology'].eq('VLMC')].sample(n_plots).iterrows():
    sample = SRRS.HDF5(stem+r['mouse_sample'])
    cell = sample.get_cells_by_id(r['cell_id'])[0]
    title = '{} cell has Flt1 peripheral score {:.2f}'.format(r['ontology'],r['score'])
    print(title)
    
    plotting.plot_cell_zslices(cell,gene_colors={'Flt1':'red'})
    plt.suptitle(title)
    fmts = [
        r['ontology'].replace('/','').replace(' ','_'),
        r['cell_id'],
        'flt1',
        '{:.2f}'.format(r['score']),
    ]
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_zslices.svg'.format(*fmts))
    plt.close()
    
    plotting.plot_cell_3D(cell,gene_colors={'Flt1':'red'})
    plt.title(title)
    plt.savefig('individual_cell_svgs/{}_{}_{}_{}_3d.svg'.format(*fmts))
    plt.close()
# Out:
# VLMC cell has Flt1 peripheral score -0.00
# VLMC cell has Flt1 peripheral score 0.08
# VLMC cell has Flt1 peripheral score 0.36
# VLMC cell has Flt1 peripheral score 0.08
# VLMC cell has Flt1 peripheral score 0.42
